# %%
import pandas as pd

# Sample sales data
data = {
    'Date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05'],
    'Region': ['North', 'South', 'East', 'West', 'North'],
    'Product': ['Laptop', 'Monitor', 'Keyboard', 'Mouse', 'Monitor'],
    'Sales': [25000, 12000, 5000, 3000, 10000]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save the data as a CSV file
df.to_csv('sales_data.csv', index=False)

# Show the data
df.head()
# Out:
#          Date Region   Product  Sales
# 0  2024-01-01  North    Laptop  25000
# 1  2024-01-02  South   Monitor  12000
# 2  2024-01-03   East  Keyboard   5000
# 3  2024-01-04   West     Mouse   3000
# 4  2024-01-05  North   Monitor  10000

# %%
# Load the file we just created
df = pd.read_csv('sales_data.csv')

# Show the first 5 rows
df.head()
# Out:
#          Date Region   Product  Sales
# 0  2024-01-01  North    Laptop  25000
# 1  2024-01-02  South   Monitor  12000
# 2  2024-01-03   East  Keyboard   5000
# 3  2024-01-04   West     Mouse   3000
# 4  2024-01-05  North   Monitor  10000

# %%
# Total sales by Region
region_sales = df.groupby('Region')['Sales'].sum()
print(region_sales)
# Out:
# Region
# East      5000
# North    35000
# South    12000
# West      3000
# Name: Sales, dtype: int64

# %%
# Total sales by Region
region_sales = df.groupby('Region')['Sales'].sum()
print(region_sales)
# Out:
# Region
# East      5000
# North    35000
# South    12000
# West      3000
# Name: Sales, dtype: int64

# %%
import matplotlib.pyplot as plt

region_sales.plot(kind='bar', title='Total Sales by Region', color='skyblue')
plt.ylabel('Sales')
plt.xlabel('Region')
plt.grid()
plt.show()

# %%
# Total sales by Product
product_sales = df.groupby('Product')['Sales'].sum()
print(product_sales)
# Out:
# Product
# Keyboard     5000
# Laptop      25000
# Monitor     22000
# Mouse        3000
# Name: Sales, dtype: int64

# %%
product_sales.plot(kind='barh', title='Total Sales by Product', color='orange')
plt.xlabel('Sales')
plt.ylabel('Product')
plt.show()
